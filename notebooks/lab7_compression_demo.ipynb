# %% [markdown]
# # CSC4005 Lab 7 – Compression Demo
#
# Notebook này chỉ minh họa luồng làm bài. Sinh viên nên chạy bằng terminal.

# %% [markdown]
# ## Quantization
# ```bash
# python -m src.quantize_onnx --input_onnx models/vit_smartcampus.onnx --output_onnx models/vit_smartcampus_dynamic_int8.onnx
# ```

# %% [markdown]
# ## Benchmark
# ```bash
# python -m src.benchmark --onnx_paths models/vit_smartcampus.onnx models/vit_smartcampus_dynamic_int8.onnx --names baseline quantized --output_csv outputs/benchmark_quantization.csv
# ```

# %% [markdown]
# ## KD
# ```bash
# python -m src.kd_train_student --teacher_checkpoint checkpoints/teacher_vit_best_model.pt --data_dir data/mit_indoor_smartcampus_5 --use_wandb
# ```
